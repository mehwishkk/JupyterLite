# %% [markdown]
# # Final Project: Data Science Tools and Practices

# %% [markdown]
# ## Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Understand basic arithmetic operations in Python
# - Convert units using Python code (e.g., minutes to hours)
# - Share a Jupyter Notebook via GitHub

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages used in Data Science are:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Some of the commonly used libraries used by Data Scientists include:-
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Category         | Description                    |
# |-----------------|------------------|--------------------------------|
# | Jupyter Notebook| IDE/Notebook     | Interactive coding             |
# | RStudio         | IDE              | Development environment for R |
# | Apache Spark    | Big Data Tool    | Fast big data processing       |
# | TensorFlow      | Deep Learning    | Neural networks and ML        |
# | Tableau         | Visualization    | Business intelligence software |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
# In this final assignment, you will:
# - Create a Jupyter Notebook
# - Insert code and markdown cells
# - Share your notebook through GitHub

# %% [markdown]
# ## Author
# Mehwish

# %% [markdown]
# ## GitHub Link
# [My Final Notebook on GitHub](https://github.com/yourusername/yourrepo)

# %% [markdown]
# ![image.png](attachment:8a393bac-4e16-4aea-b0d4-002c2e4e39a5.png)
